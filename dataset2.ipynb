# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
data = pd.read_csv("GlobalYouTubeStatistics.csv",  encoding='ISO-8859-1')
data.head(5)
# Out:
#    rank                    Youtuber  subscribers   video views  \
# 0     1                    T-Series    245000000  2.280000e+11
# 1     2              YouTube Movies    170000000  0.000000e+00
# 2     3                     MrBeast    166000000  2.836884e+10
# 3     4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4     5                   SET India    159000000  1.480000e+11
#
#            category                       Title  uploads        Country  \
# 0             Music                    T-Series    20082          India
# 1  Film & Animation               youtubemovies        1  United States
# 2     Entertainment                     MrBeast      741  United States
# 3         Education  Cocomelon - Nursery Rhymes      966  United States
# 4             Shows                   SET India   116536          India
#
#   Abbreviation   channel_type  ...  subscribers_for_last_30_days  \
# 0           IN          Music  ...                     2000000.0
# 1           US          Games  ...                           NaN
# 2           US  Entertainment  ...                     8000000.0
# 3           US      Education  ...                     1000000.0
# 4           IN  Entertainment  ...                     1000000.0
#
#    created_year  created_month  created_date  \
# 0        2006.0            Mar          13.0
# 1        2006.0            Mar           5.0
# 2        2012.0            Feb          20.0
# 3        2006.0            Sep           1.0
# 4        2006.0            Sep          20.0
#
#    Gross tertiary education enrollment (%)    Population  Unemployment rate  \
# 0                                     28.1  1.366418e+09               5.36
# 1                                     88.2  3.282395e+08              14.70
# 2                                     88.2  3.282395e+08              14.70
# 3                                     88.2  3.282395e+08              14.70
# 4                                     28.1  1.366418e+09               5.36
#
#    Urban_population   Latitude  Longitude
# 0       471031528.0  20.593684  78.962880
# 1       270663028.0  37.090240 -95.712891
# 2       270663028.0  37.090240 -95.712891
# 3       270663028.0  37.090240 -95.712891
# 4       471031528.0  20.593684  78.962880
#
# [5 rows x 28 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 995 entries, 0 to 994
# Data columns (total 28 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   rank                                     995 non-null    int64
#  1   Youtuber                                 995 non-null    object
#  2   subscribers                              995 non-null    int64
#  3   video views                              995 non-null    float64
#  4   category                                 949 non-null    object
#  5   Title                                    995 non-null    object
#  6   uploads                                  995 non-null    int64
#  7   Country                                  873 non-null    object
#  8   Abbreviation                             873 non-null    object
#  9   channel_type                             965 non-null    object
#  10  video_views_rank                         994 non-null    float64
#  11  country_rank                             879 non-null    float64
#  12  channel_type_rank                        962 non-null    float64
#  13  video_views_for_the_last_30_days         939 non-null    float64
#  14  lowest_monthly_earnings                  995 non-null    float64
#  15  highest_monthly_earnings                 995 non-null    float64
#  16  lowest_yearly_earnings                   995 non-null    float64
#  17  highest_yearly_earnings                  995 non-null    float64
#  18  subscribers_for_last_30_days             658 non-null    float64
#  19  created_year                             990 non-null    float64
#  20  created_month                            990 non-null    object
#  21  created_date                             990 non-null    float64
#  22  Gross tertiary education enrollment (%)  872 non-null    float64
#  23  Population                               872 non-null    float64
#  24  Unemployment rate                        872 non-null    float64
#  25  Urban_population                         872 non-null    float64
#  26  Latitude                                 872 non-null    float64
#  27  Longitude                                872 non-null    float64
# dtypes: float64(18), int64(3), object(7)
# memory usage: 217.8+ KB

# %%
data.describe()
# Out:
#             rank   subscribers   video views        uploads  video_views_rank  \
# count  995.00000  9.950000e+02  9.950000e+02     995.000000      9.940000e+02
# mean   498.00000  2.298241e+07  1.103954e+10    9187.125628      5.542489e+05
# std    287.37606  1.752611e+07  1.411084e+10   34151.352254      1.362782e+06
# min      1.00000  1.230000e+07  0.000000e+00       0.000000      1.000000e+00
# 25%    249.50000  1.450000e+07  4.288145e+09     194.500000      3.230000e+02
# 50%    498.00000  1.770000e+07  7.760820e+09     729.000000      9.155000e+02
# 75%    746.50000  2.460000e+07  1.355470e+10    2667.500000      3.584500e+03
# max    995.00000  2.450000e+08  2.280000e+11  301308.000000      4.057944e+06
#
#        country_rank  channel_type_rank  video_views_for_the_last_30_days  \
# count    879.000000         962.000000                      9.390000e+02
# mean     386.053470         745.719335                      1.756103e+08
# std     1232.244746        1944.386561                      4.163782e+08
# min        1.000000           1.000000                      1.000000e+00
# 25%       11.000000          27.000000                      2.013750e+07
# 50%       51.000000          65.500000                      6.408500e+07
# 75%      123.000000         139.750000                      1.688265e+08
# max     7741.000000        7741.000000                      6.589000e+09
#
#        lowest_monthly_earnings  highest_monthly_earnings  ...  \
# count               995.000000              9.950000e+02  ...
# mean              36886.148281              5.898078e+05  ...
# std               71858.724092              1.148622e+06  ...
# min                   0.000000              0.000000e+00  ...
# 25%                2700.000000              4.350000e+04  ...
# 50%               13300.000000              2.127000e+05  ...
# 75%               37900.000000              6.068000e+05  ...
# max              850900.000000              1.360000e+07  ...
#
#        highest_yearly_earnings  subscribers_for_last_30_days  created_year  \
# count             9.950000e+02                  6.580000e+02    990.000000
# mean              7.081814e+06                  3.490791e+05   2012.630303
# std               1.379704e+07                  6.143554e+05      4.512503
# min               0.000000e+00                  1.000000e+00   1970.000000
# 25%               5.217500e+05                  1.000000e+05   2009.000000
# 50%               2.600000e+06                  2.000000e+05   2013.000000
# 75%               7.300000e+06                  4.000000e+05   2016.000000
# max               1.634000e+08                  8.000000e+06   2022.000000
#
#        created_date  Gross tertiary education enrollment (%)    Population  \
# count    990.000000                               872.000000  8.720000e+02
# mean      15.746465                                63.627752  4.303873e+08
# std        8.777520                                26.106893  4.727947e+08
# min        1.000000                                 7.600000  2.025060e+05
# 25%        8.000000                                36.300000  8.335541e+07
# 50%       16.000000                                68.000000  3.282395e+08
# 75%       23.000000                                88.200000  3.282395e+08
# max       31.000000                               113.100000  1.397715e+09
#
#        Unemployment rate  Urban_population    Latitude   Longitude
# count         872.000000      8.720000e+02  872.000000  872.000000
# mean            9.279278      2.242150e+08   26.632783  -14.128146
# std             4.888354      1.546874e+08   20.560533   84.760809
# min             0.750000      3.558800e+04  -38.416097 -172.104629
# 25%             5.270000      5.590832e+07   20.593684  -95.712891
# 50%             9.365000      2.706630e+08   37.090240  -51.925280
# 75%            14.700000      2.706630e+08   37.090240   78.962880
# max            14.720000      8.429340e+08   61.924110  138.252924
#
# [8 rows x 21 columns]

# %%
data.columns
# Out:
# Index(['rank', 'Youtuber', 'subscribers', 'video views', 'category', 'Title',
#        'uploads', 'Country', 'Abbreviation', 'channel_type',
#        'video_views_rank', 'country_rank', 'channel_type_rank',
#        'video_views_for_the_last_30_days', 'lowest_monthly_earnings',
#        'highest_monthly_earnings', 'lowest_yearly_earnings',
#        'highest_yearly_earnings', 'subscribers_for_last_30_days',
#        'created_year', 'created_month', 'created_date',
#        'Gross tertiary education enrollment (%)', 'Population',
#        'Unemployment rate', 'Urban_population', 'Latitude', 'Longitude'],
#       dtype='object')

# %%
data.duplicated().sum()
# Out:
# 0

# %%
import datetime as dt
current_year = dt.datetime.now().year
ten_years_ago = current_year - 10
data = data[data['created_year'] >= ten_years_ago]
print(data[['created_year']].head(10))
# Out:
#     created_year
# 5         2013.0
# 6         2015.0
# 8         2016.0
# 9         2018.0
# 10        2014.0
# 12        2013.0
# 13        2016.0
# 16        2020.0
# 24        2013.0
# 27        2018.0

# %%
data.columns = data.columns.str.lower()
data.columns = data.columns.str.replace(' ','_')
data['video_views'] = data['video_views'].apply(lambda x: '{:.0f}'.format(float(x)))
data = data.rename(columns={'gross_tertiary_education_enrollment_(%)': 'education_enrollment'})
data['video_views'] = pd.to_numeric(data['video_views'], errors='coerce')
data.dropna(inplace=True)
print(data.head())
data.columns
# Out:
#     rank                               youtuber  subscribers  video_views  \
# 8      9                            Like Nastya    106000000  90479060027
# 9     10                          Vlad and Niki     98900000  77180169894
# 10    11                      Zee Music Company     96700000  57856289381
# 13    14                              BLACKPINK     89800000  32144597566
# 24    25  ChuChu TV Nursery Rhymes & Kids Songs     65900000  45757850229
#
#           category                                  title  uploads  \
# 8   People & Blogs                       Like Nastya Vlog      493
# 9    Entertainment                          Vlad and Niki      574
# 10           Music                      Zee Music Company     8548
# 13  People & Blogs                              BLACKPINK      543
# 24       Education  ChuChu TV Nursery Rhymes & Kids Songs      633
#
#           country abbreviation   channel_type  ...  \
# 8          Russia           RU         People  ...
# 9   United States           US  Entertainment  ...
# 10          India           IN          Music  ...
# 13    South Korea           KR          Music  ...
# 24          India           IN      Education  ...
#
#     subscribers_for_last_30_days  created_year  created_month  created_date  \
# 8                       100000.0        2016.0            Jan          14.0
# 9                       600000.0        2018.0            Apr          23.0
# 10                     1100000.0        2014.0            Mar          12.0
# 13                      700000.0        2016.0            Jun          29.0
# 24                      500000.0        2013.0            Feb           9.0
#
#     education_enrollment    population  unemployment_rate  urban_population  \
# 8                   81.9  1.443735e+08               4.59       107683889.0
# 9                   88.2  3.282395e+08              14.70       270663028.0
# 10                  28.1  1.366418e+09               5.36       471031528.0
# 13                  94.3  5.170910e+07               4.15        42106719.0
# 24                  28.1  1.366418e+09               5.36       471031528.0
#
#      latitude   longitude
# 8   61.524010  105.318756
# 9   37.090240  -95.712891
# 10  20.593684   78.962880
# 13  35.907757  127.766922
# 24  20.593684   78.962880
#
# [5 rows x 28 columns]
# Index(['rank', 'youtuber', 'subscribers', 'video_views', 'category', 'title',
#        'uploads', 'country', 'abbreviation', 'channel_type',
#        'video_views_rank', 'country_rank', 'channel_type_rank',
#        'video_views_for_the_last_30_days', 'lowest_monthly_earnings',
#        'highest_monthly_earnings', 'lowest_yearly_earnings',
#        'highest_yearly_earnings', 'subscribers_for_last_30_days',
#        'created_year', 'created_month', 'created_date', 'education_enrollment',
#        'population', 'unemployment_rate', 'urban_population', 'latitude',
#        'longitude'],
#       dtype='object')

# %%
data['created_year'] = data['created_year'].astype(int)
month_mapping = {
    'Jan': 1,
    'Feb': 2,
    'Mar': 3,
    'Apr': 4,
    'May': 5,
    'Jun': 6,
    'Jul': 7,
    'Aug': 8,
    'Sep': 9,
    'Oct': 10,
    'Nov': 11,
    'Dec': 12
}
data['created_month'] = data['created_month'].map(month_mapping)
data.head()
# Out:
#     rank                               youtuber  subscribers  video_views  \
# 8      9                            Like Nastya    106000000  90479060027
# 9     10                          Vlad and Niki     98900000  77180169894
# 10    11                      Zee Music Company     96700000  57856289381
# 13    14                              BLACKPINK     89800000  32144597566
# 24    25  ChuChu TV Nursery Rhymes & Kids Songs     65900000  45757850229
#
#           category                                  title  uploads  \
# 8   People & Blogs                       Like Nastya Vlog      493
# 9    Entertainment                          Vlad and Niki      574
# 10           Music                      Zee Music Company     8548
# 13  People & Blogs                              BLACKPINK      543
# 24       Education  ChuChu TV Nursery Rhymes & Kids Songs      633
#
#           country abbreviation   channel_type  ...  \
# 8          Russia           RU         People  ...
# 9   United States           US  Entertainment  ...
# 10          India           IN          Music  ...
# 13    South Korea           KR          Music  ...
# 24          India           IN      Education  ...
#
#     subscribers_for_last_30_days  created_year  created_month  created_date  \
# 8                       100000.0          2016              1          14.0
# 9                       600000.0          2018              4          23.0
# 10                     1100000.0          2014              3          12.0
# 13                      700000.0          2016              6          29.0
# 24                      500000.0          2013              2           9.0
#
#     education_enrollment    population  unemployment_rate  urban_population  \
# 8                   81.9  1.443735e+08               4.59       107683889.0
# 9                   88.2  3.282395e+08              14.70       270663028.0
# 10                  28.1  1.366418e+09               5.36       471031528.0
# 13                  94.3  5.170910e+07               4.15        42106719.0
# 24                  28.1  1.366418e+09               5.36       471031528.0
#
#      latitude   longitude
# 8   61.524010  105.318756
# 9   37.090240  -95.712891
# 10  20.593684   78.962880
# 13  35.907757  127.766922
# 24  20.593684   78.962880
#
# [5 rows x 28 columns]

# %%
category_profile = data.groupby('category')['subscribers'].sum().reset_index()
category_profile = category_profile.sort_values(by='subscribers', ascending=False)

country_profile = data.groupby('country')['subscribers'].sum().reset_index()
country_profile = country_profile.sort_values(by='subscribers', ascending=False)
print(country_profile)
# Out:
#                  country  subscribers
# 30         United States   1946800000
# 11                 India   1879100000
# 2                 Brazil    383800000
# 12             Indonesia    348300000
# 17                Mexico    266500000
# 21                Russia    231200000
# 0              Argentina    195400000
# 29        United Kingdom    187700000
# 23           South Korea    117200000
# 25              Thailand    107000000
# 4                  Chile     87200000
# 22          Saudi Arabia     85800000
# 28  United Arab Emirates     75300000
# 10               Germany     75200000
# 6               Colombia     69800000
# 24                 Spain     65500000
# 14                 Japan     63200000
# 27               Ukraine     59400000
# 26                Turkey     43700000
# 19              Pakistan     43200000
# 9                 France     35300000
# 32               Vietnam     34100000
# 31             Venezuela     31200000
# 8                  Egypt     30600000
# 15                Kuwait     30500000
# 7                Ecuador     27700000
# 20           Philippines     26500000
# 13                 Italy     26400000
# 16                Latvia     20200000
# 5                  China     17600000
# 1              Australia     14100000
# 18           Netherlands     13800000
# 3                 Canada     13300000

# %%
sub = list(data['subscribers'])
plt.hist(sub)
# Out:
# (array([198.,  55.,  31.,   7.,   4.,   1.,   0.,   0.,   1.,   3.]),
#  array([1.230e+07, 2.167e+07, 3.104e+07, 4.041e+07, 4.978e+07, 5.915e+07,
#         6.852e+07, 7.789e+07, 8.726e+07, 9.663e+07, 1.060e+08]),
#  <BarContainer object of 10 artists>)

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='subscribers', y='country', data=country_profile.head(10), palette='viridis' , hue = 'country')
plt.title('Top Countries by Subscribers')
plt.xlabel('Subscribers')
plt.ylabel('Country')
plt.ticklabel_format(style='plain', axis='x')

plt.show()

# %%
category_profile = data.groupby('category')['subscribers'].sum().reset_index()
category_profile = category_profile.sort_values(by='subscribers', ascending=False)
country_profile = data.groupby('country')['subscribers'].sum().reset_index()
country_profile = country_profile.sort_values(by='subscribers', ascending=False)
print("Top Content Categories by Subscribers:")
print(category_profile.head())
print("\nTop Countries by Subscribers:")
print(country_profile.head())
# Out:
# Top Content Categories by Subscribers:
#           category  subscribers
# 3    Entertainment   1849100000
# 10  People & Blogs   1303700000
# 7            Music    895400000
# 1           Comedy    569900000
# 2        Education    569800000
#
# Top Countries by Subscribers:
#           country  subscribers
# 30  United States   1946800000
# 11          India   1879100000
# 2          Brazil    383800000
# 12      Indonesia    348300000
# 17         Mexico    266500000

# %%
plt.figure(figsize=(8, 6))
sns.histplot(data=data, x='video_views', kde=True, color='skyblue', bins=30)
plt.title('Distribution of Views (Histogram)')
plt.xlabel('Video Views')
plt.ylabel('Frequency')
plt.grid(axis='y')
plt.ticklabel_format(style='plain', axis='x')

plt.show()

# %%
plt.figure(figsize=(12, 4))
sns.boxplot(data=data, x='category', y='subscribers', palette='viridis' , hue = 'category')
plt.title('Rank by Video Category')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(12, 4))
sns.boxplot(data=data, x='category', y='video_views', palette='viridis' , hue = 'category')
plt.title('Video Views by Video Category')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(data=data, x='category', y='uploads', palette='viridis' , hue = 'category')
plt.title('Uploads by Video Category')
plt.xticks(rotation=90)
plt.show()

# %%
you1 = data[['youtuber','subscribers' ,'video_views', 'category', 'uploads', 'country', 'channel_type', 'population', 'unemployment_rate', 'highest_monthly_earnings']]
you1
# Out:
#                                   youtuber  subscribers  video_views  \
# 8                              Like Nastya    106000000  90479060027
# 9                            Vlad and Niki     98900000  77180169894
# 10                       Zee Music Company     96700000  57856289381
# 13                               BLACKPINK     89800000  32144597566
# 24   ChuChu TV Nursery Rhymes & Kids Songs     65900000  45757850229
# ..                                     ...          ...          ...
# 984                   bharatzkitchen HINDI     12400000   2315226648
# 988                                 Caylus     12400000   4779139505
# 990                          Natan por Aï¿     12300000   9029609749
# 991               Free Fire India Official     12300000   1674409945
# 994                           Make Joke Of     12300000   2129773714
#
#            category  uploads        country   channel_type    population  \
# 8    People & Blogs      493         Russia         People  1.443735e+08
# 9     Entertainment      574  United States  Entertainment  3.282395e+08
# 10            Music     8548          India          Music  1.366418e+09
# 13   People & Blogs      543    South Korea          Music  5.170910e+07
# 24        Education      633          India      Education  1.366418e+09
# ..              ...      ...            ...            ...           ...
# 984   Howto & Style      729          India          Howto  1.366418e+09
# 988       Education     1340  United States          Games  3.282395e+08
# 990          Sports     1200         Brazil  Entertainment  2.125594e+08
# 991  People & Blogs     1500          India          Games  1.366418e+09
# 994          Comedy       62          India         Comedy  1.366418e+09
#
#      unemployment_rate  highest_monthly_earnings
# 8                 4.59                  195800.0
# 9                14.70                 2300000.0
# 10                5.36                 3200000.0
# 13                4.15                 2000000.0
# 24                5.36                 1700000.0
# ..                 ...                       ...
# 984               5.36                  123900.0
# 988              14.70                  710400.0
# 990              12.08                 2200000.0
# 991               5.36                  258900.0
# 994               5.36                   96000.0
#
# [300 rows x 10 columns]
